# %% [markdown]
# # Final Project

# %% [markdown]
# This notebook is for my final project of course 2

# %% [markdown]
# There are various data science languages:
# 1. Scala
# 2. Python
# 3. R
# 4. C++

# %% [markdown]
# There are various data science libraries:
# 1. numpy
# 2. pandas
# 3. matplotlib

# %% [markdown]
# |Data science tools|
# |----------------------------------------------|
# |RStudio|
# |Jupyter notebook|
# |MySQL|
# |Tableau|

# %% [markdown]
# ### This is a simple arithmetic expression:

# %%
(4*5)+20
# Out:
# 40

# %%
mins = 100
hours = mins/60
print (hours)
# Out:
# 1.6666666666666667

# %% [markdown]
# ## Objectives
#
# - Learn jupyter notebook
# - List libraries
# - Learn popular data science languages

# %% [markdown]
# ### Author
# Pranshu Verma
